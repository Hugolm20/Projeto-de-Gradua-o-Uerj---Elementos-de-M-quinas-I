# %%
D = 38/1000
L = 38.1/1000
C = 0.076/1000
W = 2224
rpm = 1800
u = 0.0276

# %%
x = L * D
p = W / x
print(p)
# Out:
# 1536123.774001934

# %%
S = ((u* (rpm/60))/p)*(D/C)**2

print(S)
# Out:
# 0.1347547661870503
