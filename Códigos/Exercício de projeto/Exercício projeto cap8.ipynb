# %%
from decimal import *
getcontext().prec = 4

# %%
d = Decimal(46.2) #encontrado na questão de projeto do cap 7
P = Decimal(104.43)
p_adm = Decimal(4.8)
n = Decimal(10)
t= Decimal(5.4)
rpm = Decimal(2500)

# %%
#conversão da potencia em watts e rotação em rad/s
pot = P * Decimal(745.7)
rot = rpm * Decimal(0.1047)

#cálculo da torção
T = pot / rot

# %%
print(pot)
print(rot)
# Out:
# 7.787E+4
# 261.8

# %%
#cálculo do comprimento
L = d*Decimal(1.25)

#cálculo do D (diâmetro maior)
D = d + (Decimal(2)*t)

# %%
print(T)
print(D)
# Out:
# 297.4
# 57.00
