# %%
d = 36
l = 64
tensao_adm_cis = 55
torque = 390

# %%
tensao_adm_comp = tensao_adm_cis / 0.577

t = (2 * torque) / (tensao_adm_comp * l * (d/2))

b = torque / (tensao_adm_cis * l * (d/2))

if t > b:
  print(f't = {t:2f} m')
else:
  print(f'b = {b:2f} m')
# Out:
# t = 0.007103 m
