# %%
     t = 12.7
     b = 9.5
     d = 38
     tensao_adm_cis = 55
     tensao_adm_comp = 110
     m = 680

# %%
l = m / (tensao_adm_cis * b * (d/2))

print(f'l = {l:2f} m')
# Out:
# l = 0.068497 m
