# %%
n = 10
d_maior = 57
t = 5.4
l = 44.5
p_adm = 4.8
N = 2500

# %%
d_menor = d_maior - (2 * t)

r_m = (d_maior + d_menor) / 4

torque = r_m * p_adm * t * l * n

P = (torque * 10**-3) * (2500 / 9.55)
print(f'Potência : {P:.2f} Watts')
# Out:
# Potência : 77902.49 Watts
