# %%
C = 190
L10 = '' 
F = 190
rpm = 2000 
#responder com s ou n
mancais_esferas = 's'

# %%
if mancais_esferas == 's':
  a = 3
else:
  a = 1/3

# %%
if C == '':
  C = F * ((60*rpm*L10)/10**6)**(1/a)
  print(f'C: {C:.2f} kN')
elif L10 == '':
  L10 = ((10**6)/(60*rpm)) * (C/F)**a
  print(f'L10: {L10:.2f} horas')
# Out:
# L10: 8.33 horas
