# %%
from numpy import log 
import math

# %%
L = 1800
R = 0.999

# %%
#cálculo da vida nominal
L10 = L / (6.84 * (log(1/R))**0.854 )

print(f'L10: {L10:.0f} horas')
# Out:
# L10: 95947 horas

# %%
L = 15000
L10 = 20000

# %%
R = math.exp(-(L / (6.84* L10))**1.17)
print(R)
# Out:
# 0.9274634259916869
