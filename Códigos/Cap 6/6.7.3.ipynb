# %%
import math
import numpy as np

# %% [markdown]
# ### Dados de entrada

# %%
# valor das cargas aplicadas
V = 16000
H = 16000
f = [[0,16000],[16000,0]]


#ponto de aplicação das cargas
F = [0.500,0.160]

#posicionamento dos parafusos
p = [[0,0.120], [0.150, 0.120], [0.150,0], [0,0]]

#áreas dos parafusos
a = [[1],[1],[1],[1]]

t = 10
d = 16

# %% [markdown]
# ### Cálculo do Centroide

# %%
#Cálculo do centroide 
i = 0
b = []
c = []

for i in range(0,len(p)):

  x_barra = (p[i][0] * a[i][0]) / len(p) * a[i][0]
  y_barra = (p[i][1] * a[i][0]) / len(p) * a[i][0]

  x_barra = b.append(x_barra)
  y_barra = c.append(y_barra)

  x_barra = sum(b)
  y_barra = sum(c)

  i = i + 1

G = [x_barra,y_barra]

# %%
G
# Out:
# [0.075, 0.06]

# %% [markdown]
# ### Distância entre o centróide e ponto de aplicação das cargas (GF)

# %%
#Distância entre o centroide e o ponto de aplicação das cargas (GF)
GF = [F[0]-G[0],F[1]-G[1]]

# %%
GF
# Out:
# [0.425, 0.1]

# %% [markdown]
# ### Distância entre o parafuso e o centróide (ri)

# %%
i = 0
r = []

while i < len(p):  
  x = math.sqrt((p[i][0] - G[0])**2  + (p[i][1] - G[1])**2)
  r.append(x)

  i = i+1

# %%
r
# Out:
# [0.09604686356149274,
#  0.09604686356149274,
#  0.09604686356149274,
#  0.09604686356149274]

# %% [markdown]
# ### Momento resultante

# %%
def prod_vet(matriz_posicao, matriz_forca):
  i = 0
  a = []

  while i < len(matriz_posicao):
      prod = np.cross(matriz_posicao[i], matriz_forca[i])
      prod = a.append(prod)
      prod = sum(a)
      i = i + 1
  
  return prod

# %%
j = 0
MR = []
while j < len(f):
  y = prod_vet([GF], [f[j]])
  MR.append(y)
  j = j + 1

# %%
MR
# Out:
# [6800.0, -1600.0]

# %%
MR = MR[0] + MR[1]

# %%
MR
# Out:
# 5200.0

# %% [markdown]
# ### Vetor GA (entre o centróide e ponto de aplicação da carga no parafuso)

# %%
#Vetor GA
i = 0
x = []

while i < len(p):
  GA = [p[i][0] - G[0],p[i][1]-G[1]]
  x.append(GA)
  i = i + 1

GA = x
print(GA)
# Out:
# [[-0.075, 0.06], [0.075, 0.06], [0.075, -0.06], [-0.075, -0.06]]

# %% [markdown]
# ### Vetor Q (perpendicular ao GA)

# %%
# vetor Q
if MR > 0:
  i = 0
  while i < len(GA):
    GA[i][0],GA[i][1] = -GA[i][1],GA[i][0]  
    i = i + 1
else:
  i = 0
  while i < len(GA):
    GA[i][0],GA[i][1] = GA[i][1],-GA[i][0]
    i = i + 1
Q = GA
print(Q)
# Out:
# [[-0.06, -0.075], [-0.06, 0.075], [0.06, 0.075], [0.06, -0.075]]

# %% [markdown]
# ### Vetor unitário de Q (u)
# (saber a direção)

# %%
#cálculo do vetor unitário para saber a direção de Q
i = 0 
x = []
while i < len(Q):
  u = [Q[i][0]/math.sqrt( ((Q[i][0])**2)  + ((Q[i][1])**2) ),Q[i][1]/math.sqrt( ((Q[i][0])**2)  + ((Q[i][1])**2) )]
  x.append(u)
  i = i + 1

u = x
print(u)
# Out:
# [[-0.6246950475544242, -0.7808688094430303], [-0.6246950475544242, 0.7808688094430303], [0.6246950475544242, 0.7808688094430303], [0.6246950475544242, -0.7808688094430303]]

# %% [markdown]
# ### Força resultante Q

# %% [markdown]
# Segundo a apostila, para achar o valor de Q, fazemos:
# Q1 = r1 * Mg  / r1² + r2² + ... + rn²

# %%
r
# Out:
# [0.09604686356149274,
#  0.09604686356149274,
#  0.09604686356149274,
#  0.09604686356149274]

# %%
#tratamento de dados para elevar a segunda potência todos os elementos da matriz r e depois somá-los.
i = 0
x = []
while i < len(r):
  a = r[i]**2
  x.append(a)
  i = i+1 

a = sum(x)

# %%
i = 0
q = []

while i < len(r):
  Q = r[i]*MR / a
  q.append(Q)
  i = i + 1

# %%
q
# Out:
# [13535.059363679193,
#  13535.059363679193,
#  13535.059363679193,
#  13535.059363679193]

# %% [markdown]
# ### Multiplicando a força Q pelo vetor unitário
# (assim eu tenho um vetor Qi+Qj)

# %%
#multiplicando a força Q pelo vetor unitário
i = 0
x = []

while i < len(q):
  Q = [q[i]*u[i][0],q[i]*u[i][1]]
  x.append(Q)
  i = i + 1

Q = x
print(Q)
# Out:
# [[-8455.284552845527, -10569.10569105691], [-8455.284552845527, 10569.10569105691], [8455.284552845527, 10569.10569105691], [8455.284552845527, -10569.10569105691]]

# %% [markdown]
# ### Encontrar as forças F do parafuso mais tensionado

# %%
i = 0
x = []

while i < len(Q):
  F = [Q[i][0] + (V/len(p)), Q[i][1] + (H/len(p))]
  x.append(F)
  i = i + 1
x
# Out:
# [[-4455.284552845527, -6569.10569105691],
#  [-4455.284552845527, 14569.10569105691],
#  [12455.284552845527, 14569.10569105691],
#  [12455.284552845527, -6569.10569105691]]

# %%
i = 0
y = []
while i < len(Q):
  F = [math.sqrt(x[i][0]**2 + x[i][1]**2)]
  y.append(F)
  i = i + 1

F = y
F
# Out:
# [[7937.42464701872],
#  [15235.104236073043],
#  [19167.49733088645],
#  [14081.45102156126]]

# %%
Fi = max(F)

# %%
Fi
# Out:
# [19167.49733088645]

# %% [markdown]
# ### Tensão Cisalhamento

# %%
tensao_cisalhamento = (4*Fi[0])  /(3.14* d**2)

tensao_cisalhamento
# Out:
# 95.37966426595565

# %% [markdown]
# ### Tensão de compressão superficial

# %%
tensao_compressao = Fi[0] / (d*t)

tensao_compressao
# Out:
# 119.79685831804031
