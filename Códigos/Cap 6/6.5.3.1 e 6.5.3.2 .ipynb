# %%
at = 483 * 10**-6  
rp = 380 * 10**6
p = 180000
d = 0.025

# para fi com fixação permanente x = 0. 
# para fi com fixação não permanente x = 1
x = 0

fat_seg

# para t sem lubrificação y = 0
# para t com lubrificação y = 1
y = 0

if y == 0:
    t = 0.2 * d * fi
else:
    t = 0.15 * d * fi

fp = (1/9 * p) + fi 
fm = (8/9 * p) - fi 

print(f'{fi:.0f} N')
print(f'{t:.0f} N')
print(f'{fp:.0f} N')
print(f'{fm:.0f} N')
# Out:
# 165186 N
# 826 N
# 185186 N
# -5186 N
